# %%
import json
with open('/Users/kellyji/.secret/yelp_api.json') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# !pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from yelpapi) (2.29.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->yelpapi) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->yelpapi) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->yelpapi) (3.4)

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'],timeout_s=5.0)
yelp_api

# %%
search_results=yelp_api.search_query(location='Seattle,WA',term='Sushi')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 912

# %%
import pandas as pd
biz=pd.DataFrame(search_results['businesses'])
biz.head(3)
# Out:
#                        id                  alias           name  \
# 0  YSQiqH7RIWORk_Qp-A4SOg         shiros-seattle        Shiro's
# 1  3hxncVCRPfmKLOyiXKXbDw  sushi-kashiba-seattle  Sushi Kashiba
# 2  vs5dhED5Yf8kqPp06OD2QQ         momiji-seattle         Momiji
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/hcw9Ea...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/shiros-seattle?adjust...          2608
# 1  https://www.yelp.com/biz/sushi-kashiba-seattle...          1402
# 2  https://www.yelp.com/biz/momiji-seattle?adjust...          1825
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 47.6147782162181, 'longitude': -1...  [pickup, delivery]
# 1  {'latitude': 47.6099251, 'longitude': -122.341...          [delivery]
# 2    {'latitude': 47.61482, 'longitude': -122.31657}          [delivery]
#
#   price                                           location         phone  \
# 0  $$$$  {'address1': '2401 2nd Ave', 'address2': '', '...  +12064439844
# 1  $$$$  {'address1': '86 Pine St', 'address2': 'Ste 1'...  +12064418844
# 2    $$  {'address1': '1522 12th Ave', 'address2': '', ...  +12064574068
#
#     display_phone     distance
# 0  (206) 443-9844  1477.968059
# 1  (206) 441-8844  1781.219913
# 2  (206) 457-4068  1847.275584

# %%
search_results = yelp_api.search_query(location='NY,NY',term='Pizza',offset=40)
biz20=pd.DataFrame(search_results['businesses'])
biz20.head(3)
# Out:
#                        id                               alias  \
# 0  iicRfXfltjzhi_m_O_sfpw  lil-frankies-of-bay-ridge-brooklyn
# 1  i_rg-OLXQbpRUN7O3MeCeA         piz-zetta-pizzeria-brooklyn
# 2  ZFaIpks0AmQKdFvqYbj0QQ           barbalu-brooklyn-brooklyn
#
#                          name  \
# 0  Lil Frankie's of Bay Ridge
# 1          Piz-zetta Pizzeria
# 2          Barbalu - Brooklyn
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/x8lCG0...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/rEKWLF...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/KbWbJT...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/lil-frankies-of-bay-r...             9
# 1  https://www.yelp.com/biz/piz-zetta-pizzeria-br...           345
# 2  https://www.yelp.com/biz/barbalu-brooklyn-broo...            84
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     5.0
# 1  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.6344210655883, 'longitude': -7...  [delivery, pickup]
# 1  {'latitude': 40.69116658201196, 'longitude': -...  [delivery, pickup]
# 2  {'latitude': 40.68675727907743, 'longitude': -...  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '279 71st St', 'address2': None, ...  +17182387100
# 1  {'address1': '90 Livingston St', 'address2': '...  +17184227878
# 2  {'address1': '68 Bergen St', 'address2': None,...  +13472944287
#
#     display_phone     distance price
# 0  (718) 238-7100  8365.975630   NaN
# 1  (718) 422-7878  1616.959411     $
# 2  (347) 294-4287  2096.255371   NaN

# %%
businesses=pd.concat([biz,biz20],ignore_index=True)
display(businesses.head(3),businesses.tail(3))
# Out:
#                        id                  alias           name  \
# 0  YSQiqH7RIWORk_Qp-A4SOg         shiros-seattle        Shiro's
# 1  3hxncVCRPfmKLOyiXKXbDw  sushi-kashiba-seattle  Sushi Kashiba
# 2  vs5dhED5Yf8kqPp06OD2QQ         momiji-seattle         Momiji
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/hcw9Ea...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/kDUe-m...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/oQgt6B...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/shiros-seattle?adjust...          2608
# 1  https://www.yelp.com/biz/sushi-kashiba-seattle...          1402
# 2  https://www.yelp.com/biz/momiji-seattle?adjust...          1825
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 47.6147782162181, 'longitude': -1...  [pickup, delivery]
# 1  {'latitude': 47.6099251, 'longitude': -122.341...          [delivery]
# 2    {'latitude': 47.61482, 'longitude': -122.31657}          [delivery]
#
#   price                                           location         phone  \
# 0  $$$$  {'address1': '2401 2nd Ave', 'address2': '', '...  +12064439844
# 1  $$$$  {'address1': '86 Pine St', 'address2': 'Ste 1'...  +12064418844
# 2    $$  {'address1': '1522 12th Ave', 'address2': '', ...  +12064574068
#
#     display_phone     distance
# 0  (206) 443-9844  1477.968059
# 1  (206) 441-8844  1781.219913
# 2  (206) 457-4068  1847.275584
#                         id                              alias  \
# 37  m3PS0tIaa0ChcP8Y5S-DrQ                 mamas-too-new-york
# 38  AHDlsNh8fODK9miC3zv3Zg         unregular-pizza-new-york-2
# 39  ON7ihGoWgZaBFDaLCYpk2Q  rome-to-brooklyn-pizza-brooklyn-2
#
#                       name                                          image_url  \
# 37             MAMA'S TOO!  https://s3-media2.fl.yelpcdn.com/bphoto/DxUBQK...
# 38         Unregular Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/o91Xby...
# 39  Rome To Brooklyn Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/4JavGL...
#
#     is_closed                                                url  \
# 37      False  https://www.yelp.com/biz/mamas-too-new-york?ad...
# 38      False  https://www.yelp.com/biz/unregular-pizza-new-y...
# 39      False  https://www.yelp.com/biz/rome-to-brooklyn-pizz...
#
#     review_count                                         categories  rating  \
# 37           718  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 38           249  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 39           172  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
#
#                                           coordinates        transactions  \
# 37     {'latitude': 40.80084, 'longitude': -73.96766}          [delivery]
# 38  {'latitude': 40.73368221456629, 'longitude': -...  [delivery, pickup]
# 39  {'latitude': 40.711886016839244, 'longitude': ...  [delivery, pickup]
#
#    price                                           location         phone  \
# 37    $$  {'address1': '2750 Broadway', 'address2': '', ...  +12125107256
# 38    $$  {'address1': '135 4th Ave', 'address2': None, ...  +16466094699
# 39   NaN  {'address1': '755 Grand St', 'address2': None,...  +17182693239
#
#      display_phone      distance
# 37  (212) 510-7256  10840.163727
# 38  (646) 609-4699   3164.662726
# 39  (718) 269-3239   4390.674583

# %%
businesses.to_json('/Users/kellyji/Documents/DataEnrichment/Yelp-API-/yelp_sushi_seattle_search.json', orient='records')
