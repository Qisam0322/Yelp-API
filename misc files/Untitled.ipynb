# %%
import json
with open('/Users/kellyji/.secret/yelp_api.json') as f:
    login = json.load(f)

login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# !pip install yelpapi

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'],timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
search_results=yelp_api.search_query(location='NY,NY',term='pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 12300

# %%
import pandas as pd
biz=pd.DataFrame(search_results['businesses'])
biz.head(3)
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 2  v1DHGRNCH9247WLYoaoA9A   l-industrie-pizzeria-brooklyn
#
#                    name                                          image_url  \
# 0             Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1   Prince Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...
# 2  L'industrie Pizzeria  https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2721
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5121
# 2      False  https://www.yelp.com/biz/l-industrie-pizzeria-...          1180
#
#                                           categories  rating  \
# ...

# %%
search_results = yelp_api.search_query(location='NY,NY',term='Pizza',offset=40)
biz20=pd.DataFrame(search_results['businesses'])
biz20.head(3)
# Out:
#                        id                               alias  \
# 0  C8j0q4Ma_S5hBGuAI-aaww              di-fara-pizza-brooklyn
# 1  iicRfXfltjzhi_m_O_sfpw  lil-frankies-of-bay-ridge-brooklyn
# 2  i_rg-OLXQbpRUN7O3MeCeA         piz-zetta-pizzeria-brooklyn
#
#                          name  \
# 0               Di Fara Pizza
# 1  Lil Frankie's of Bay Ridge
# 2          Piz-zetta Pizzeria
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/HWI1IP...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/x8lCG0...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/rEKWLF...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/di-fara-pizza-brookly...          4002
# 1  https://www.yelp.com/biz/lil-frankies-of-bay-r...             9
# 2  https://www.yelp.com/biz/piz-zetta-pizzeria-br...           345
#
# ...

# %%
businesses=pd.concat([biz,biz20],ignore_index=True)
display(businesses.head(3),businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 2  v1DHGRNCH9247WLYoaoA9A   l-industrie-pizzeria-brooklyn
#
#                    name                                          image_url  \
# 0             Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1   Prince Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/2-U43P...
# 2  L'industrie Pizzeria  https://s3-media1.fl.yelpcdn.com/bphoto/1-VBwA...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2721
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5121
# 2      False  https://www.yelp.com/biz/l-industrie-pizzeria-...          1180
#
#                                           categories  rating  \
# ...
